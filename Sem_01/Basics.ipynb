# %% [markdown]
# # Let's start on the basics. Variables and arrays

# %% [markdown]
# ### First, import some libraries

# %%
import numpy as np

# %%
print("-------Arrays-------")
array_1 = np.array([0,1,2,3,4,5,6])
print(array_1)
array_2 = np.random.randint(7,size=(1,7))
print(array_2)

print("-------Arrays Shape-------")

print("array 1: ",array_1.shape)
print("array 2: ",array_2.shape)

print("-------Arrays Summation-------")

summ_1=np.sum(array_1)
summ_2=np.sum(array_2)

print("Summation Array 1:", summ_1)
print("Summation Array 2:", summ_2)

_ # print both array_1 and array_2
_ # print both array_1 and array_2 shapes
_ # print summation of array_1 and array_2
# Out:
# -------Arrays-------
# [0 1 2 3 4 5 6]
# [[6 2 6 1 4 4 6]]
# -------Arrays Shape-------
# array 1:  (7,)
# array 2:  (1, 7)
# -------Arrays Summation-------
# Summation Array 1: 21
# Summation Array 2: 29
# ''

# %%
_ # Replace the value of array_1 in pos 3 by 70
print("-------Array Replaced-------")

array_replaced=array_1[3]=70
print(array_replaced)
print("-------Array Replaced Summation-------")

summr_1=np.sum(array_replaced)
print("Summation pos replaced", summr_1)
_ # Print summation again
# Out:
# -------Array Replaced-------
# 70
# -------Array Replaced Summation-------
# Summation pos replaced 70
# ''

# %%
_ # Apply element-wise multiplication among array_1 and array_2
print("-------Array multiplication-------")

multiplication=np.multiply(array_1,array_2)
print(multiplication)
_ # Print results
# Out:
# -------Array multiplication-------
# [[ 0  2 12 70 16 20 36]]
# ''

# %% [markdown]
# # Playing with some images! Introduction to OpenCV
#
# Download the image [lena.jpg](https://drive.google.com/file/d/1gH5sJN__2g7f9ndLhLvTECdOBJIGUbg_/view) before getting started!

# %% [markdown]
# ### First, let's mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import some libraries

# %%
# Import some libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load an image using OpenCV

# %%
# Loading a color image
img = cv2.imread('/content/drive/MyDrive/ML/machine_learning/Images/lena.png')
_
plt.imshow(img) # plots an image

# %% [markdown]
# ### Let's play with the data

# %%
# Printing the image shape (size of the image)
print("-------image shape-------")

print(img.shape)
# Out:
# -------image shape-------
# (439, 440, 3)

# %%
# Looking through the image...
# print among image indexes
print(img.index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-692666aee582> in <cell line: 0>()
#       1 # Looking through the image...
#       2 # print among image indexes
# ----> 3 print(img.index)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
print (type(img),img.shape)
# Out:
# <class 'numpy.ndarray'> (439, 440, 3)

# %%
for i in range(0,10):
  print(img[0,i,1])
print("OTHER PRINT")
img_matrix=img[0:10,0:10,1],type[0:10]
print(img_matrix)
# Out:
# 111
# 111
# 111
# 111
# 118
# 118
# 118
# 118
# 111
# 111
# OTHER PRINT
# (array([[111, 111, 111, 111, 118, 118, 118, 118, 111, 111],
#        [111, 118, 111, 118, 111, 118, 111, 118, 111, 111],
#        [118, 111, 118, 111, 118, 111, 118, 118, 111, 104],
#        [118, 118, 118, 118, 111, 111, 111, 118, 111, 104],
#        [118, 118, 111, 118, 111, 111, 111, 111, 111, 111],
#        [118, 111, 118, 118, 111, 111, 111, 118, 111, 103],
#        [111, 113, 111, 111, 111, 111, 111, 104, 103, 103],
#        [111, 111, 111, 111, 111, 111, 111, 103, 111, 104],
#        [111, 104, 111, 111, 111, 111, 111, 111, 103, 111],
#        [111, 111, 111, 111, 111, 111, 103, 103, 103, 103]], dtype=uint8), type[slice(0, 10, None)])

# %%
# img[0:100,0:100,0]=255
# img[0:100,0:100,1]=255
# img[0:100,0:100,2]=0
img[0:100,0:100,0:3]=200

plt.imshow(img)

# %%
img_shorted=img[150:350,150:320,0:3]
plt.imshow(img_shorted)

# %%
img[100:300,0:170,0:3]=img_shorted
plt.imshow(img)

# %% [markdown]
# ### Load an image in grayscale

# %%
# Loading a color image in grayscale
img_gray = cv2.imread( _ )
plt.imshow(img_gray, _ )

# %% [markdown]
# ### Play with the image

# %%
# Printing the image shape
_

# %%
# Regarding through the image... Again

# %% [markdown]
# ### Going further

# %%
# Messing everything around.
img = cv2.imread( _ )
_
plt.imshow(img_gray, _ )

# %%
# Playing with image intensities
img_gray = cv2.imread( _ )

for r in _  :  # Go through rows
  for c in _ : # Go through cols
    if _ : # Create a simple condition
      _ # Do something

plt.imshow(img_gray, _ )

# %% [markdown]
# ### Save an image using OpenCV

# %%
cv2.imwrite('newlena.png',img_gray)

# %% [markdown]
# ### Crop the image - taking regions of interest (ROI)

# %%
# Extract some ROI
roi = _
plt.imshow(roi, _ )

# %%
img_gray[ _ , _ ] = roi
plt.imshow(img_gray, _ )

# %% [markdown]
# ## Load an image using pillow (PIL)

# %%
from PIL import Image

# %%
# Loading a color image
img = Image.open( _ )
plt.imshow(img) # plots an image

# %%
print (img[:10, :10]) ## Error. This is not an array

# %%
img = np.asarray( _ ) ## Convert to an array
print (img[ _ , _ ]) ## Now it works!
print (img.shape)

# %% [markdown]
# ### Load the image in grayscale

# %%
img = Image.open( _ ).convert("L")
plt.imshow(img, _ ) # plots an image
