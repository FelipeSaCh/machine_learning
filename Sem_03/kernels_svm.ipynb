# %% [markdown]
# # **SVM - Kernel comparison**

# %% [markdown]
# ## Kernel interpretation

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from PIL import Image
from sklearn.svm import SVC
from sklearn.datasets import make_gaussian_quantiles

# %%
X, y = make_gaussian_quantiles(cov=2,
                                 n_samples = 300 , n_features = 2 ,
                                 n_classes = 2 , random_state = 1)

X[y==0,:]=X[y==0,:]*0.5
_,ax=plt.subplots(figsize=(5,4))
ax.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap="Dark2")

# %%
k=X[:,0]**2+X[:,1]**2
X=np.c_[X,k]
print(X.shape)
# Out:
# (300, 3)

# %%
f,_=plt.subplots(figsize=(5,4))
ax=f.add_subplot(projection='3d')
ax.view_init(0, 0)
ax.scatter3D(X[:,0], X[:,1], k, c=y, s=10, cmap="Dark2")

h_grid,v_grid=np.meshgrid(np.linspace(-4,4,100),np.linspace(-4,6,100))
z_grid=np.ones(h_grid.shape)*1.5

ax.plot_surface(h_grid,v_grid,z_grid,color='k',alpha=0.5)
ax.set_zlim(-0.1,5)
plt.tight_layout()

# %%
import os

os.makedirs("images", exist_ok=True)

# %%
# Sve all figs

for i in range(0,191,10):
  f,_=plt.subplots(figsize=(5,4))
  ax=f.add_subplot(projection='3d')
  ax.view_init(i, 45)
  ax.scatter3D(X[:,0], X[:,1], k, c=y, s=10, cmap="Dark2")
  ax.plot_surface(h_grid,v_grid,z_grid,color='k',alpha=0.5)
  ax.set_zlim(-0.1,5)
  plt.tight_layout()
  plt.savefig('images/{0}.png'.format(i))

# %%
import os
from PIL import Image
all_images=[]

for file_ in sorted(os.listdir('images/')):
  image=Image.open('images/{0}'.format(file_))
  all_images.append(image)
# Save a gif
_

image.save("kernel_.gif", save_all=True, append_images=all_images, duration=200, loop=0)

# %% [markdown]
# ## SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_classification

# %%
# we create 100 separable points
X, Y = make_classification(n_samples = _ , n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=2, random_state=2)
plt.scatter( _ , _ , c = _ , s = _, cmap=plt.cm.Paired)

# %%
kernels = ['linear', 'poly', 'rbf','sigmoid']

_, axes = plt.subplots(1,4, figsize = (20,5))

# fit the model
for i, kernel in enumerate(kernels) :
    #
    clf = svm.SVC(kernel = kernel , gamma = 1)
    clf.fit( X , y )

    x_min,x_max=X[:,0].min()-0.1,X[:,0].max()+0.1
    y_min,y_max=X[:,1].min()-0.1,X[:,1].max()+0.1

    x_grid,y_grid=np.meshgrid(np.arange(x_min,x_max,0.1),np.arange(y_min,y_max,0.1))
    pred_grid = clf.predict(np.c_[x_grid.ravel(), y_grid.ravel()])

    pred_grid = pred_grid.reshape( _ )
    axes[i].pcolormesh( x_grid , y_grid, pred_grid, cmap = 'Dark2')
    # axes[i].contour( _ , _ , predictions, colors=['k', 'k'], linestyles=['-', '-'], levels=[0, 1])

    axes[i].scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s = 90, facecolors = 'none', edgecolors = 'k')

    axes[i].scatter( X[:,0] ,X[:,1] , c = y , cmap='Dark2', edgecolors='k')
    axes[i].set_axis_off()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-a8e229b9d5c9> in <cell line: 0>()
#      13
#      14     x_grid,y_grid=np.meshgrid(np.arange(x_min,x_max,0.1),np.arange(y_min,y_max,0.1))
# ---> 15     pred_grid = clf.predict(np.c_[x_grid.ravel(), y_grid.ravel()])
#      16
#      17     pred_grid = pred_grid.reshape( _ )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     820             y = np.argmax(self.decision_function(X), axis=1)
#     821         else:
# --> 822             y = super().predict(X)
#     823         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     824
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     434             The predicted values.
#     435         """
# --> 436         X = self._validate_for_predict(X)
#     437         predict = self._sparse_predict if self._sparse else self._dense_predict
#     438         return predict(X)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     612
#     613         if not callable(self.kernel):
# --> 614             X = validate_data(
#     615                 self,
#     616                 X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2963
#    2964     if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965         _check_n_features(_estimator, X, reset=reset)
#    2966
#    2967     return out
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in _check_n_features(estimator, X, reset)
#    2827
#    2828     if n_features != estimator.n_features_in_:
# -> 2829         raise ValueError(
#    2830             f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831             f"is expecting {estimator.n_features_in_} features as input."
#
# ValueError: X has 2 features, but SVC is expecting 3 features as input.

# %%
kernels = ['linear', 'poly', 'rbf','sigmoid']

_, axes = plt.subplots(1,4, figsize = (20,5))

# fit the model
for i, kernel in enumerate(kernels) :
    #
    clf = svm.SVC(kernel = kernel , gamma = 1)
    clf.fit( X , y )

    x_min,x_max=X[:,0].min()-0.1,X[:,0].max()+0.1
    y_min,y_max=X[:,1].min()-0.1,X[:,1].max()+0.1

    x_grid,y_grid=np.meshgrid(np.arange(x_min,x_max,0.01),np.arange(y_min,y_max,0.01))
    # Calculate the third feature for the prediction grid
    k_grid = x_grid**2 + y_grid**2
    # Include the third feature in the prediction data
    pred_grid = clf.predict(np.c_[x_grid.ravel(), y_grid.ravel(), k_grid.ravel()])

    pred_grid = pred_grid.reshape(x_grid.shape) # Reshape to match x_grid
    axes[i].pcolormesh( x_grid , y_grid, pred_grid, cmap = 'Dark2')
    # axes[i].contour( _ , _ , predictions, colors=['k', 'k'], linestyles=['-', '-'], levels=[0, 1])

    axes[i].scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s = 90, facecolors = 'none', edgecolors = 'k')

    axes[i].scatter( X[:,0] ,X[:,1] , c = y , cmap='Dark2', edgecolors='k')
    axes[i].set_axis_off()

plt.show()

# %%
kernels = ['linear', 'poly', 'rbf']

_, axes = plt.subplots(1,3, figsize = (20,5))

# fit the model
for i, kernel in enumerate(kernels):
    #
    clf = svm.SVC(kernel = _ , gamma = 1)
    clf.fit( _ , _ )

    x_min, x_max = _ , _
    y_min, y_max = _ , _

    x_dim, y_dim = np.meshgrid(np.arange( _ , _ , 0.01), np.arange( _ , _ , 0.01))
    predictions = clf.decision_function(np.c_[x_dim.ravel(), y_dim.ravel()])

    predictions = predictions.reshape(x_dim.shape)
    axes[i].pcolormesh( _ , _ , predictions, cmap = plt.cm.coolwarm)
    axes[i].contourf( _ , _ , predictions, alpha = 0.75, cmap = plt.cm.coolwarm)

    axes[i].scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s = 90, facecolors = 'none', edgecolors = 'k')

    axes[i].scatter( _ , _ , c=Y, cmap=plt.cm.coolwarm, edgecolors='k')
    axes[i].set_axis_off()

plt.show()

# %% [markdown]
# Create a function that plots the decision boundaries of a given SVM

# %% [markdown]
# ## In real data

# %% [markdown]
# Evaluate the different SVM kernels in the Iris and Fruits datasets
